# %%
import pandas as pd

# %%
import os

# %%
stanford_breeds = [name.split('-')[1] for name in os.listdir('./stanford/images/Images')]
stanford_breeds
# Out:
# ['Bernese_mountain_dog',
#  'Australian_terrier',
#  'Eskimo_dog',
#  'Samoyed',
#  'Bedlington_terrier',
#  'dhole',
#  'Irish_setter',
#  'Welsh_springer_spaniel',
#  'schipperke',
#  'Blenheim_spaniel',
#  'miniature_schnauzer',
#  'Bouvier_des_Flandres',
#  'Newfoundland',
#  'Tibetan_mastiff',
#  'malinois',
#  'English_foxhound',
#  'collie',
#  'flat',
#  'Tibetan_terrier',
#  'standard_poodle',
#  'German_short',
#  'curly',
#  'Dandie_Dinmont',
#  'West_Highland_white_terrier',
#  'cocker_spaniel',
#  'briard',
#  'Old_English_sheepdog',
#  'Yorkshire_terrier',
#  'Great_Dane',
#  'keeshond',
#  'Weimaraner',
#  'English_springer',
#  'Sussex_spaniel',
#  'Chesapeake_Bay_retriever',
#  'Doberman',
#  'Saluki',
#  'toy_poodle',
#  'toy_terrier',
#  'Labrador_retriever',
#  'Kerry_blue_terrier',
#  'Scotch_terrier',
#  'Gordon_setter',
#  'Walker_hound',
#  'whippet',
#  'papillon',
#  'Italian_greyhound',
#  'malamute',
#  'standard_schnauzer',
#  'komondor',
#  'Leonberg',
# ...

# %%
oxford_breeds = list(set([('_').join(name.split('_')[:-1]) for name in os.listdir('./oxford/images')]))
oxford_breeds
# Out:
# ['english_setter',
#  'chihuahua',
#  'shiba_inu',
#  'yorkshire_terrier',
#  'samoyed',
#  'Siamese',
#  'leonberger',
#  'Egyptian_Mau',
#  'Birman',
#  'newfoundland',
#  'scottish_terrier',
#  'english_cocker_spaniel',
#  'Ragdoll',
#  'Russian_Blue',
#  'japanese_chin',
#  'Abyssinian',
#  'wheaten_terrier',
#  'saint_bernard',
#  'boxer',
#  'pug',
#  'Bombay',
#  'Maine_Coon',
#  'staffordshire_bull_terrier',
#  'german_shorthaired',
#  'american_bulldog',
#  'keeshond',
#  'Persian',
#  'British_Shorthair',
#  'Bengal',
#  'american_pit_bull_terrier',
#  'pomeranian',
#  'basset_hound',
#  'miniature_pinscher',
#  'havanese',
#  'beagle',
#  'great_pyrenees',
#  'Sphynx']

# %%
other_breeds = list(set([name.split('.')[1] for name in os.listdir('./dogImages/train')]))
other_breeds
# Out:
# ['English_setter',
#  'Pomeranian',
#  'Irish_water_spaniel',
#  'Afghan_hound',
#  'Cairn_terrier',
#  'American_eskimo_dog',
#  'Kerry_blue_terrier',
#  'Entlebucher_mountain_dog',
#  'Papillon',
#  'Norwegian_lundehund',
#  'Chihuahua',
#  'Akita',
#  'Silky_terrier',
#  'Giant_schnauzer',
#  'English_cocker_spaniel',
#  'Dogue_de_bordeaux',
#  'Belgian_malinois',
#  'Alaskan_malamute',
#  'Old_english_sheepdog',
#  'Great_dane',
#  'American_water_spaniel',
#  'Petit_basset_griffon_vendeen',
#  'Japanese_chin',
#  'Maltese',
#  'Newfoundland',
#  'Cane_corso',
#  'Poodle',
#  'Irish_terrier',
#  'Black_and_tan_coonhound',
#  'Australian_shepherd',
#  'Ibizan_hound',
#  'Dachshund',
#  'Boykin_spaniel',
#  'Welsh_springer_spaniel',
#  'Chesapeake_bay_retriever',
#  'Brussels_griffon',
#  'Leonberger',
#  'Bulldog',
#  'Labrador_retriever',
#  'Parson_russell_terrier',
#  'German_shepherd_dog',
#  'Saint_bernard',
#  'Curly-coated_retriever',
#  'Bluetick_coonhound',
# ...
